# %%
#cell the Libraries
import numpy as np              
import pandas  as pd                         
import matplotlib.pyplot as plt                                   
import seaborn as sns                                     
from sklearn.model_selection import train_test_split,GridSearchCV 
from sklearn.model_selection import KFold ,cross_val_score
from sklearn.preprocessing import StandardScaler ,LabelEncoder 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier 
from sklearn.metrics import ConfusionMatrixDisplay,confusion_matrix ,accuracy_score

# %%
#read the dataset
df=pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
#infirmation the dataset
df.head()
# Out:
#    customerID  gender  SeniorCitizen Dependents2 Dependents  tenure  \
# 0  7590-VHVEG  Female              0         Yes         No       1
# 1  5575-GNVDE    Male              0          No         No      34
# 2  3668-QPYBK    Male              0          No         No       2
# 3  7795-CFOCW    Male              0          No         No      45
# 4  9237-HQITU  Female              0          No         No       2
#
#   PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0           No  No phone service             DSL             No  ...
# 1          Yes                No             DSL            Yes  ...
# 2          Yes                No             DSL            Yes  ...
# 3           No  No phone service             DSL            Yes  ...
# 4          Yes                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Dependents2       7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#cheak the null 
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Dependents2         0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#cheak the duplicated
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Dependents2 Dependents  tenure  \
# 0  7590-VHVEG  Female              0         Yes         No       1
# 1  5575-GNVDE    Male              0          No         No      34
# 2  3668-QPYBK    Male              0          No         No       2
# 3  7795-CFOCW    Male              0          No         No      45
# 4  9237-HQITU  Female              0          No         No       2
#
#   PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0           No  No phone service             DSL             No  ...
# 1          Yes                No             DSL            Yes  ...
# 2          Yes                No             DSL            Yes  ...
# 3           No  No phone service             DSL            Yes  ...
# 4          Yes                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
#explorting the data analysis 
df["gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df["gender"].value_counts().plot(kind="pie")
plt.title("pie in gender")
plt.show()

# %%
df["SeniorCitizen"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["SeniorCitizen"].value_counts().plot(kind="bar")
plt.title("bar the seniorcitizen")
plt.show()

# %%
df["InternetService"].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
df["InternetService"].value_counts().plot(kind="hist",color="g")
plt.title("hist in the Internetservice")
plt.show()

# %%
df["Contract"].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
df["Contract"].value_counts().plot(kind="barh",color="k")
plt.title("bart in the contract")
plt.show()

# %%
df["PaymentMethod"].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
df["PaymentMethod"].value_counts().plot(kind="bar")
plt.title("bar in the aymentMethod")
plt.show()

# %%
df["MonthlyCharges"].value_counts().plot(kind="density")
plt.title("density in the Monthlycharges")
plt.show()

# %%
df["TotalCharges"].value_counts().plot(kind="density")
plt.title("density in the totalcharhes")
plt.show()

# %%
label=LabelEncoder()
df["gender"]=label.fit_transform(df["gender"])
df["MultipleLines"]=label.fit_transform(df["MultipleLines"])
df["InternetService"]=label.fit_transform(df["InternetService"])
df["Contract"]=label.fit_transform(df["Contract"])
df["PaymentMethod"]=label.fit_transform(df["PaymentMethod"])
df["Churn"]=label.fit_transform(df["Churn"])
df["PaperlessBilling"]=label.fit_transform(df["PaperlessBilling"])
df["StreamingMovies"]=label.fit_transform(df["StreamingMovies"])
df["StreamingTV"]=label.fit_transform(df["StreamingTV"])
df["TechSupport"]=label.fit_transform(df["TechSupport"])
df["DeviceProtection"]=label.fit_transform(df["DeviceProtection"])
df["OnlineBackup"]=label.fit_transform(df["OnlineBackup"])
df["OnlineSecurity"]=label.fit_transform(df["OnlineSecurity"])
df["PhoneService"]=label.fit_transform(df["PhoneService"])
df["Dependents"]=label.fit_transform(df["Dependents"])
df["Dependents"]=label.fit_transform(df["Dependents"])
df["SeniorCitizen"]=label.fit_transform(df["SeniorCitizen"])
df["TotalCharges"]=label.fit_transform(df["TotalCharges"])
df["Dependents2"]=label.fit_transform(df["Dependents2"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int32
#  2   SeniorCitizen     7043 non-null   int64
#  3   Dependents2       7043 non-null   int32
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int32
#  7   MultipleLines     7043 non-null   int32
#  8   InternetService   7043 non-null   int32
#  9   OnlineSecurity    7043 non-null   int32
#  10  OnlineBackup      7043 non-null   int32
#  11  DeviceProtection  7043 non-null   int32
#  12  TechSupport       7043 non-null   int32
#  13  StreamingTV       7043 non-null   int32
#  14  StreamingMovies   7043 non-null   int32
#  15  Contract          7043 non-null   int32
# ...

# %%
#feature selection
df=df.drop(["customerID"],axis=1)

# %%
df
# Out:
#       gender  SeniorCitizen  Dependents2  Dependents  tenure  PhoneService  \
# 0          0              0            1           0       1             0
# 1          1              0            0           0      34             1
# 2          1              0            0           0       2             1
# 3          1              0            0           0      45             0
# 4          0              0            0           0       2             1
# ...      ...            ...          ...         ...     ...           ...
# 7038       1              0            1           1      24             1
# 7039       0              0            1           1      72             1
# 7040       0              0            1           1      11             0
# 7041       1              1            1           0       4             1
# 7042       1              0            0           0      66             1
#
# ...

# %%
z=df.corr()
plt.figure(figsize=(30,30))
sns.heatmap(z ,annot=True)
# Out:
# <Axes: >

# %%
#check the outliear
plt.figure(figsize=(30,30))
plt.title("boxplot in the data")
sns.boxplot(df)

plt.show()

# %%
#split the dataset 
x=df.drop(["Churn"],axis=1)
y=df["Churn"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,shuffle=True,test_size=0.2,random_state=42)

# %%
x_test.shape
# Out:
# (1409, 19)

# %%
y_test.shape
# Out:
# (1409,)

# %%
model1=DecisionTreeClassifier(criterion= "log_loss", max_depth= 40, max_features="sqrt", min_samples_leaf= 5, min_samples_split= 40, splitter= "random")

# %%
parmeter={


"criterion":['gini', 'entropy', 'log_loss'] ,
"splitter": ['best', 'random'] ,
"max_depth" : [20,25,30,40],
"min_samples_split":[20,10,30,40],
"min_samples_leaf" :[1,2,3,4,5,6,7,8,9],

"max_features":['auto', 'sqrt', 'log2'] 
 }

# %%
gred_search=GridSearchCV(model1,parmeter,cv=5,n_jobs=-1)
gred_search.fit(x_train,y_train)
# Out:
# c:\Users\Golden-Tech\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 4320 fits failed out of a total of 12960.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 3518 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Golden-Tech\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Golden-Tech\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Golden-Tech\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
# ...

# %%
print(gred_search.best_params_)
# Out:
# {'criterion': 'log_loss', 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 40, 'splitter': 'random'}

# %%
model2=RandomForestClassifier(bootstrap= True, max_depth= 20, max_features= 'sqrt', min_samples_leaf= 2, min_samples_split= 40, n_estimators= 20)

# %%
Parmeter2={
"n_estimators":[5,10,20,30],
"max_depth" : [20,25,30,40],
"min_samples_split":[20,10,30,40],
"min_samples_leaf" :[1,2,3,4,5,6,7,8,9],
"bootstrap":[True,False],
"max_features":['auto', 'sqrt'], 
}

# %%
gred_search2=GridSearchCV(model2,Parmeter2,cv=5,n_jobs=-1)
gred_search2.fit(x_train,y_train)
# Out:
# c:\Users\Golden-Tech\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 5760 fits failed out of a total of 11520.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4800 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Golden-Tech\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Golden-Tech\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Golden-Tech\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
# ...

# %%
print(gred_search2.best_params_)
# Out:
# {'bootstrap': False, 'max_depth': 30, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 30, 'n_estimators': 30}

# %%
model3=XGBClassifier()

# %%
voot=VotingClassifier(
    estimators=[ 
        ("mo1",model1),
        ("mo2",model2),
        ("mo3",model3)
    ],
    voting="hard"
)

# %%
voot.fit(x_train,y_train)
# Out:
# VotingClassifier(estimators=[('mo1',
#                               DecisionTreeClassifier(criterion='log_loss',
#                                                      max_depth=40,
#                                                      max_features='sqrt',
#                                                      min_samples_leaf=5,
#                                                      min_samples_split=40,
#                                                      splitter='random')),
#                              ('mo2',
#                               RandomForestClassifier(max_depth=20,
#                                                      min_samples_leaf=2,
#                                                      min_samples_split=40,
#                                                      n_estimators=20)),
#                              ('mo3',
#                               XGBClassifier(base_score=None, booster=None,
# ...

# %%
k=KFold(n_splits=5,shuffle=True,random_state=42)
cross_val_score(voot,x,y,cv=k)
# Out:
# array([0.8105039 , 0.81689141, 0.78566359, 0.796875  , 0.80397727])

# %%
y_pred=voot.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7998580553584103

# %%
cm=confusion_matrix(y_test,y_pred)
cmd=ConfusionMatrixDisplay(cm)                     
cmd.plot()
